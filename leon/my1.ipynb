# %%
# dir 0.5 pFedSD resnet
import json
import matplotlib.pyplot as plt

with open('../checkpoint/cifar10/resnet8/demo/20231022224437_algo-fedavg_moon_lr-0.01_n_comm_rounds-100_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-1.0/0/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = [
    data[i]['top1'] for i in range(lenth) if data[i]['type'] == "average_test"
]
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 231
# ...

# %%
with open('../checkpoint/cifar10/resnet8/demo/comm=100_20231016223757_algo-fedavg_con_moon_lr-0.01_n_comm_rounds-100_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-1.0/0/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = [
    data[i]['top1'] for i in range(lenth) if data[i]['type'] == "average_test"
]
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 2100
# ...

# %%
with open('../checkpoint/cifar10/resnet8/demo/20231022225642_algo-fedavg_moon_lr-0.01_n_comm_rounds-100_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-1.0/0/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = [
    data[i]['top1'] for i in range(lenth) if data[i]['type'] == "average_test"
]
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 189
# ...

# %%
with open('../checkpoint/cifar10/resnet8/demo/20231019132156_algo-pFedSD_lr-0.01_n_comm_rounds-100_local_n_epochs-5_batchsize-64_n_clients-100_participation_ratio-0.1/0/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = [
    data[i]['top1'] for i in range(lenth) if data[i]['type'] == "average_test"
]
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 2280
# ...

# %%
with open('../checkpoint/cifar10/resnet8/demo/20231023001532_algo-fedavg_con_moon_lr-0.01_n_comm_rounds-100_local_n_epochs-5_batchsize-256_n_clients-50_participation_ratio-0.2/0/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = [
    data[i]['top1'] for i in range(lenth) if data[i]['type'] == "average_test"
]
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 815
# ...
