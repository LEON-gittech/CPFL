# %%
import json
import matplotlib.pyplot as plt

# %%
with open('../checkpoint/cifar10/simple_cnn/demo/20230917231857_algo-fedavg_lr-0.01_n_comm_rounds-50_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-1.0/0/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = []
for i in range(lenth):
    if "average_test" in data[i]['type']:
        result_per_round.append(data[i]['top1'])
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 1050
# ...

# %%
with open('../checkpoint/cifar10/resnet8/demo/20230919124548_algo-pFedSD_lr-0.01_n_comm_rounds-50_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-1.0/0/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = [
    data[i]['top1'] for i in range(lenth) if data[i]['type'] == "average_test"
]
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 1050
# ...

# %%
with open('../checkpoint/cifar10/resnet8/demo/20231010221339_algo-pFedSD_con_lr-0.01_n_comm_rounds-30_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-1.0/0/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = [
    data[i]['top1'] for i in range(lenth) if data[i]['type'] == "average_test"
]
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 630
# ...

# %%
with open('../checkpoint/cifar10/resnet8/demo/20230920221224_algo-pFedSD_lr-0.01_n_comm_rounds-30_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-1.0/0/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = [
    data[i]['top1'] for i in range(lenth) if data[i]['type'] == "average_test"
]
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 630
# ...

# %%
with open('../checkpoint/cifar10/resnet8/demo/20230920221224_algo-pFedSD_lr-0.01_n_comm_rounds-30_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-1.0/1/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = []
for i in range(lenth):
    # if data[i]['epoch']==5.0:
    if "top1" in data[i]:
        result_per_round.append(data[i]['top1'])
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 189
# ...

# %%
with open('../checkpoint/cifar10/resnet14/demo/20230921100528_algo-pFedSD_lr-0.01_n_comm_rounds-30_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-1.0/0/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = [
    data[i]['top1'] for i in range(lenth) if data[i]['type'] == "average_test"
]
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 630
# ...

# %%
with open('../checkpoint/cifar10/resnet14/demo/20230921151145_algo-pFedSD_lr-0.01_n_comm_rounds-30_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-1.0/0/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = [
    data[i]['top1'] for i in range(lenth) if data[i]['type'] == "average_test"
]
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 630
# ...

# %%
with open('../checkpoint/cifar10/resnet8/demo/20231003200111_algo-fedavg_lr-0.01_n_comm_rounds-30_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-0.6/0/log-1.json/0/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = [
    data[i]['top1'] for i in range(lenth) if data[i]['type'] == "average_test"
]
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 462
# ...

# %%
with open('../checkpoint/cifar10/resnet8/demo/20230921103658_algo-pFedSD_lr-0.01_n_comm_rounds-30_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-1.0/0/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = [
    data[i]['top1'] for i in range(lenth) if data[i]['type'] == "average_test"
]
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 630
# ...

# %%
with open('../checkpoint/cifar10/resnet8/demo/20230921111005_algo-pFedSD_lr-0.01_n_comm_rounds-30_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-1.0/0/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = [
    data[i]['top1'] for i in range(lenth) if data[i]['type'] == "average_test"
]
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 399
# ...

# %%
with open('../checkpoint/cifar10/simple_cnn/demo/20230917232338_algo-pFedSD_lr-0.01_n_comm_rounds-50_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-1.0/1/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = []
for i in range(lenth):
    # if data[i]['epoch']==5.0:
    if "top1" in data[i]:
        result_per_round.append(data[i]['top1'])
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 291
# ...

# %%
with open('../checkpoint/cifar10/simple_cnn/demo/20230917232338_algo-pFedSD_lr-0.01_n_comm_rounds-50_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-1.0/2/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = []
for i in range(lenth):
    if data[i]['epoch']==5.0:
        if "top1" in data[i]:
            result_per_round.append(data[i]['top1'])
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 291
# ...

# %%
for i in range(250):
    plt.scatter(i,result_per_round[i], label='数据点', color='blue', marker='o')
    if(i%5==0):plt.plot(int(i/5),result_per_round[int(i/5)], label='连接线', color='green', linestyle='--')
plt.grid(True)
# plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_306486/4198288675.py in <module>
#       1 for i in range(250):
# ----> 2     plt.scatter(i,result_per_round[i], label='数据点', color='blue', marker='o')
#       3     if(i%5==0):plt.plot(int(i/5),result_per_round[int(i/5)], label='连接线', color='green', linestyle='--')
#       4 plt.grid(True)
#       5 # plt.legend()
#
# IndexError: list index out of range

# %%
with open('../checkpoint/cifar10/simple_cnn/demo/20230917232338_algo-pFedSD_lr-0.01_n_comm_rounds-50_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-1.0/2/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = []
for i in range(lenth):
    if (i+1)%5 ==0:
        if "top1" in data[i]:
            result_per_round.append(data[i]['top1'])
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 291
# ...

# %%
with open('../checkpoint/cifar10/simple_cnn/demo/20230917231857_algo-fedavg_lr-0.01_n_comm_rounds-50_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-1.0/2/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = []
for i in range(lenth):
    if (i+1)%5 ==0:
        if "top1" in data[i]:
            result_per_round.append(data[i]['top1'])
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 296
# ...

# %%
with open('../checkpoint/cifar10/simple_cnn/demo/20230917231857_algo-fedavg_lr-0.01_n_comm_rounds-50_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-1.0/3/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = []
for i in range(lenth):
    if (i+1)%5 ==0:
        if "top1" in data[i]:
            result_per_round.append(data[i]['top1'])
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 296
# ...

# %%
with open('../checkpoint/cifar10/resnet8/demo/20231003200111_algo-fedavg_lr-0.01_n_comm_rounds-30_local_n_epochs-5_batchsize-64_n_clients-10_participation_ratio-0.6/0/log-1.json','r') as file:
    data = json.load(file)

print(len(data))
print(data)
lenth  = len(data)
result_per_round = [
    data[i]['top1'] for i in range(lenth) if data[i]['type'] == "GM_average_test"
]
print(result_per_round)
print(len(result_per_round))
plt.plot(result_per_round)
plt.show()
# Out:
# 630
# ...
