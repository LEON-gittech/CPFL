data_dir_0_1=[(0, [(1, 129), (3, 307), (4, 1), (5, 119), (8, 1958), (9, 3486)]), (1, [(0, 1), (2, 2144), (4, 1838), (9, 2017)]), (2, [(0, 1818), (1, 98), (3, 1800), (4, 2284)]), (3, [(0, 199), (1, 1433), (2, 224), (3, 3206), (4, 547), (6, 78), (7, 313)]), (4, [(1, 3246), (2, 95), (4, 231), (5, 365), (6, 2063)]), (5, [(0, 280), (1, 638), (2, 39), (3, 230), (4, 201), (5, 1484), (6, 3128)]), (6, [(0, 3253), (1, 379), (2, 1635), (6, 728), (8, 5)]), (7, [(2, 1862), (3, 448), (4, 712), (5, 2), (7, 2976)]), (8, [(1, 76), (3, 3), (6, 2), (7, 2709), (8, 3210)]), (9, [(0, 449), (1, 1), (2, 1), (3, 6), (4, 186), (5, 4030), (6, 1), (7, 2), (8, 827), (9, 497)])]
data_dir_pat=[(0, [(1, 2500), (7, 2500)]), (1, [(2, 2500), (5, 2500)]), (2, [(0, 2500), (1, 2500)]), (3, [(6, 2500), (8, 2500)]), (4, [(3, 2500), (9, 2500)]), (5, [(0, 2500), (4, 2500)]), (6, [(6, 2500), (8, 2500)]), (7, [(2, 2500), (9, 2500)]), (8, [(3, 2500), (7, 2500)]), (9, [(4, 2500), (5, 2500)])]
# 提取数据并创建矩阵
matrix = np.zeros((10, 10))
for client_id, class_data in data_dir_0_5:
    for class_id, count in class_data:
        matrix[client_id][class_id] = count

# 创建热力图
plt.figure(figsize=(10, 6))
sns.heatmap(matrix, annot=True, cmap="YlGnBu", fmt="g")
plt.xlabel("Class")
plt.ylabel("Client")
plt.title("Distribution of Classes Across Clients Dir=0.5")
plt.show()

# %%
# 提取数据并创建矩阵
matrix = np.zeros((10, 10))
for client_id, class_data in data_dir_1:
    for class_id, count in class_data:
        matrix[client_id][class_id] = count

# 创建热力图
plt.figure(figsize=(10, 6))
sns.heatmap(matrix, annot=True, cmap="YlGnBu", fmt="g")
plt.xlabel("Class")
plt.ylabel("Client")
plt.title("Distribution of Classes Across Clients Dir=1.0")
plt.show()

# %%
# 提取数据并创建矩阵
matrix = np.zeros((10, 10))
for client_id, class_data in data_dir_0_01:
    for class_id, count in class_data:
        matrix[client_id][class_id] = count

# 创建热力图
plt.figure(figsize=(10, 6))
sns.heatmap(matrix, annot=True, cmap="YlGnBu", fmt="g")
plt.xlabel("Class")
plt.ylabel("Client")
plt.title("Distribution of Classes Across Clients Dir=0.01")
plt.show()

# %%
# 提取数据并创建矩阵
matrix = np.zeros((10, 10))
for client_id, class_data in data_dir_0_1:
    for class_id, count in class_data:
        matrix[client_id][class_id] = count

# 创建热力图
plt.figure(figsize=(10, 6))
sns.heatmap(matrix, annot=True, cmap="YlGnBu", fmt="g")
plt.xlabel("Class")
plt.ylabel("Client")
plt.title("Distribution of Classes Across Clients Dir=0.1")
)]), (74, [(2, 102), (4, 176), (5, 322)]), (75, [(0, 43), (1, 1), (2, 12), (3, 20), (4, 62), (5, 128), (6, 8), (8, 326)]), (76, [(0, 196), (4, 363), (5, 9), (8, 32)]), (77, [(0, 88), (1, 1), (2, 1), (3, 63), (4, 1), (5, 12), (6, 434)]), (78, [(0, 1), (1, 2), (2, 22), (3, 101), (4, 1), (5, 25), (6, 120), (7, 323), (8, 5)]), (79, [(8, 5), (9, 595)]), (80, [(1, 45), (5, 26), (7, 3), (8, 1), (9, 525)]), (81, [(1, 202), (2, 72), (3, 16), (5, 121), (8, 86), (9, 103)]), (82, [(0, 499), (8, 101)]), (83, [(0, 59), (1, 139), (2, 44), (4, 82), (5, 13), (8, 263)]), (84, [(2, 25), (4, 279), (5, 296)]), (85, [(0, 35), (1, 164), (4, 272), (5, 115), (7, 6), (8, 3), (9, 5)]), (86, [(0, 26), (1, 23), (3, 527), (6, 24)]), (87, [(2, 26), (3, 23), (5, 5), (6, 4), (7, 542)]), (88, [(0, 2), (1, 19), (2, 436), (6, 12), (7, 12), (8, 119)]), (89, [(1, 36), (2, 1), (3, 4), (4, 1), (5, 6), (6, 551), (8, 1)]), (90, [(2, 31), (3, 298), (4, 25), (5, 6), (9, 240)]), (91, [(0, 4), (2, 276), (3, 132), (4, 7), (6, 2), (7, 179)]), (92, [(0, 11), (1, 153), (2, 227), (3, 8), (6, 201)]), (93, [(0, 8), (1, 291), (2, 70), (3, 1), (5, 227), (6, 1), (7, 1), (8, 1)]), (94, [(0, 270), (5, 330)]), (95, [(0, 89), (1, 2), (2, 1), (3, 54), (4, 2), (6, 96), (7, 356)]), (96, [(1, 7), (2, 6), (3, 1), (6, 30), (7, 60), (8, 416), (9, 80)]), (97, [(3, 44), (4, 319), (9, 237)]), (98, [(0, 184), (1, 74), (2, 2), (3, 90), (4, 15), (5, 39), (7, 1), (8, 174), (9, 21)]), (99, [(1, 85), (2, 1), (3, 1), (4, 232), (5, 1), (6, 279), (9, 1)])]
matrix = np.zeros((100, 10))
for client_id, class_data in data:
    for class_id, count in class_data:
        matrix[client_id][class_id] = count

# 创建热力图
plt.figure(figsize=(10, 10))
sns.heatmap(matrix, annot=True, cmap="YlGnBu", fmt="t")
plt.xlabel("Class")
plt.ylabel("Client")
plt.title("Distribution of Classes Across Clients Dir=0.1, client=100")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4187968/292485807.py in <module>
#      12 # 创建热力图
#      13 plt.figure(figsize=(10, 10))
# ---> 14 sns.heatmap(matrix, annot=True, cmap="YlGnBu", fmt="t")
#      15 plt.xlabel("Class")
#      16 plt.ylabel("Client")
#
# ~/miniconda3/envs/fed_d/lib/python3.7/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457     if square:
#     458         ax.set_aspect("equal")
# --> 459     plotter.plot(ax, cbar_ax, kwargs)
#     460     return ax
#     461
#
# ~/miniconda3/envs/fed_d/lib/python3.7/site-packages/seaborn/matrix.py in plot(self, ax, cax, kws)
#     350         # Annotate the cells with the formatted values
#     351         if self.annot:
# ...
